# %% [markdown]
# # Factor Analysis for Pooled Experiments 1, 2, and 3
#
# This notebook mirrors `factor-analysis-exp1-exp2-exp3.ipynb` and reuses the same preprocessing from:
# - `Experiment1/analysis/analysis-0306.ipynb`
# - `Experiment2/analysis/0325.ipynb`
# - `Experiment3/analysis/analysis-0318.ipynb`
#
# Difference from the original notebook:
# - after preprocessing each experiment, all treatment rows are pooled into one combined dataset
# - factor analysis is run once on the pooled dataset (treated as one experiment)
#
# Factor models:
# - **1-4** factors for trust/usability questions
# - **1-9** factors for interaction-experience questions
#
# Final outputs:
# - one combined loading table for interaction questions from the pooled analysis
# - pooled factor-model metrics table
# - LaTeX exports: `factor-pooled.tex` and `interaction-factor-metrics-pooled.tex`
# - interaction metric trend figures in `analysis_outputs/pooled/`

# %%
import json
import re
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import display
from sklearn.decomposition import FactorAnalysis

warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 200)
pd.set_option("display.width", None)

# %%
TRUST_QUESTION_KEYS = [
    "skeptical_rating",
    "data_trust",
    "usability_difficulty",
    "comprehension_ease",
]

INTERACTION_QUESTION_KEYS = [
    "navigation_control",
    "content_control",
    "pace_control",
    "interface_exploration",
    "interface_responsiveness",
    "user_communication",
    "personal_conversation",
    "interface_interaction",
    "interface_sensitivity",
]

TRUST_PROMPT_MAP = {
    "skeptical_rating": "I was skeptical of the visualization output.",
    "data_trust": "I trusted the data shown by the visualization.",
    "usability_difficulty": "The visualization was difficult to use.",
    "comprehension_ease": "The visualization made the task easier to understand.",
}

INTERACTION_PROMPT_MAP = {
    "navigation_control": "I was in control of my navigation through this interface.",
    "content_control": "I had control over the content I wanted to inspect.",
    "pace_control": "I was in control of the pace of my visit to this interface.",
    "interface_exploration": "The interface supported the way I wanted to explore the visualization.",
    "interface_responsiveness": "The interface responded quickly and efficiently to what I wanted to inspect.",
    "user_communication": "The interface supported communication with other users who shared my interests.",
    "personal_conversation": "Interacting with the interface felt like a personal conversation.",
    "interface_interaction": "I felt that I could interact meaningfully with the interface.",
    "interface_sensitivity": "The interface felt sensitive to my actions.",
}

TRUST_FACTOR_COUNTS = [1, 2, 3, 4]
INTERACTION_FACTOR_COUNTS = list(range(1, 10))
INTERACTION_METRIC_FACTOR_COUNTS = [n_factors for n_factors in INTERACTION_FACTOR_COUNTS if n_factors != 9]
LOADING_TABLE_FACTOR_COUNTS = [3]
FACTOR_COUNTS = sorted(set(TRUST_FACTOR_COUNTS + INTERACTION_FACTOR_COUNTS))
LOADING_THRESHOLD = 0.3
OBLIMIN_GAMMA = 0.0
OBLIMIN_MAX_ITER = 500
OBLIMIN_TOL = 1e-5
OBLIMIN_KAISER_NORMALIZE = True


def find_project_root(start=None):
    start = Path.cwd() if start is None else Path(start).resolve()
    for candidate in [start, *start.parents]:
        if (candidate / "Experiment1").exists() and (candidate / "Experiment2").exists() and (candidate / "Experiment3").exists():
            return candidate
    raise FileNotFoundError("Could not find project root containing Experiment1/Experiment2/Experiment3")


PROJECT_ROOT = find_project_root()
print(f"Project root: {PROJECT_ROOT}")
# Out:
# Project root: /Users/songwen/Documents/Code Lab/Interact4Trust

# %%
def parse_response_json(value):
    if pd.isna(value):
        return {}
    if isinstance(value, dict):
        return value
    try:
        parsed = json.loads(value)
        return parsed if isinstance(parsed, dict) else {}
    except Exception:
        return {}


def expand_response_columns(data, response_col="response"):
    if response_col not in data.columns:
        return data.copy()

    parsed = data[response_col].apply(parse_response_json)
    expanded = pd.json_normalize(parsed)

    merged = data.reset_index(drop=True).copy()
    for col in expanded.columns:
        parsed_values = expanded[col]
        if col in merged.columns:
            merged[col] = merged[col].where(merged[col].notna(), parsed_values)
        else:
            merged[col] = parsed_values

    return merged


def ensure_likert_columns(data, keys):
    if data.empty:
        return data.copy()

    working = data.copy()
    parsed = (
        working["response"].apply(parse_response_json)
        if "response" in working.columns
        else pd.Series([{}] * len(working), index=working.index)
    )

    for key in keys:
        existing = (
            pd.to_numeric(working[key], errors="coerce")
            if key in working.columns
            else pd.Series(np.nan, index=working.index)
        )

        if key not in working.columns or existing.notna().sum() == 0:
            extracted = pd.to_numeric(parsed.apply(lambda d: d.get(key, np.nan)), errors="coerce")
            valid = extracted.dropna()
            if not valid.empty and (valid >= 0).all() and (valid <= 6).all():
                extracted = extracted + 1
            working[key] = extracted
        else:
            working[key] = existing

    return working

# %%
NORMALIZED_FLAG_COLUMN = "_cousineau_normalized"
MOREY_FACTOR_COLUMN = "_morey_factor"
K_CONDITIONS_COLUMN = "_k_conditions"


def identify_attention_check_failures(
    data,
    trust_keys=TRUST_QUESTION_KEYS,
    interaction_keys=INTERACTION_QUESTION_KEYS,
    survey_trial_type="trust-survey",
):
    if data is None or data.empty:
        return set(), pd.DataFrame()

    if "trial_type" not in data.columns or "participant_id" not in data.columns:
        return set(), pd.DataFrame()

    survey_rows = data[data["trial_type"] == survey_trial_type].copy()
    if survey_rows.empty:
        return set(), pd.DataFrame()

    survey_rows = expand_response_columns(survey_rows)
    parsed_response = (
        survey_rows["response"].apply(parse_response_json)
        if "response" in survey_rows.columns
        else pd.Series([{}] * len(survey_rows), index=survey_rows.index)
    )

    for key in trust_keys + interaction_keys:
        existing = (
            pd.to_numeric(survey_rows[key], errors="coerce")
            if key in survey_rows.columns
            else pd.Series(np.nan, index=survey_rows.index)
        )
        if existing.notna().sum() == 0:
            existing = pd.to_numeric(parsed_response.apply(lambda d: d.get(key, np.nan)), errors="coerce")
        survey_rows[key] = existing

    trust_complete = survey_rows[trust_keys].notna().all(axis=1)
    interaction_complete = survey_rows[interaction_keys].notna().all(axis=1)

    trust_uniform = survey_rows[trust_keys].nunique(axis=1, dropna=True).eq(1)
    interaction_uniform = survey_rows[interaction_keys].nunique(axis=1, dropna=True).eq(1)

    failure_mask = trust_complete & interaction_complete & trust_uniform & interaction_uniform
    failure_rows = survey_rows[failure_mask & survey_rows["participant_id"].notna()].copy()

    if failure_rows.empty:
        return set(), pd.DataFrame()

    failure_rows["participant_id"] = failure_rows["participant_id"].astype(str)
    detail_columns = [
        "participant_id",
        "condition_id",
        "condition_number",
        *trust_keys,
        *interaction_keys,
    ]
    available_detail_columns = [col for col in detail_columns if col in failure_rows.columns]
    return set(failure_rows["participant_id"].unique()), failure_rows[available_detail_columns].reset_index(drop=True)


def normalize_scores_cousineau_morey(
    data,
    metric_columns,
    baseline_condition=1,
    drop_baseline=True,
    normalization_conditions=None,
    require_complete_participants=True,
):
    if data is None or data.empty:
        normalized = pd.DataFrame() if data is None else data.copy()
        if not normalized.empty:
            normalized[NORMALIZED_FLAG_COLUMN] = False
            normalized[MOREY_FACTOR_COLUMN] = np.nan
            normalized[K_CONDITIONS_COLUMN] = np.nan
        return normalized

    required_cols = {"participant_id", "condition_number"}
    if not required_cols.issubset(data.columns):
        normalized = data.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        normalized[K_CONDITIONS_COLUMN] = np.nan
        return normalized

    available_columns = [col for col in metric_columns if col in data.columns]
    if not available_columns:
        normalized = data.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        normalized[K_CONDITIONS_COLUMN] = np.nan
        return normalized

    working = data.copy()
    working["condition_number"] = pd.to_numeric(working["condition_number"], errors="coerce")
    working[NORMALIZED_FLAG_COLUMN] = False
    working[MOREY_FACTOR_COLUMN] = np.nan
    working[K_CONDITIONS_COLUMN] = np.nan

    if normalization_conditions is None:
        observed_conditions = working["condition_number"].dropna().astype(int).unique().tolist()
        normalization_conditions = sorted(c for c in observed_conditions if c != int(baseline_condition))
    else:
        normalization_conditions = sorted({int(c) for c in normalization_conditions})

    if not normalization_conditions:
        if drop_baseline:
            working = working[working["condition_number"] != baseline_condition].copy()
        return working.reset_index(drop=True)

    normalization_mask = working["condition_number"].isin(normalization_conditions)
    normalization_data = working[normalization_mask].copy()
    if normalization_data.empty:
        if drop_baseline:
            working = working[working["condition_number"] != baseline_condition].copy()
        return working.reset_index(drop=True)

    expected_k = len(normalization_conditions)

    if require_complete_participants:
        participant_condition_counts = (
            normalization_data.groupby("participant_id", dropna=False)["condition_number"]
            .nunique()
        )
        complete_participants = participant_condition_counts[
            participant_condition_counts >= expected_k
        ].index
        normalization_data = normalization_data[
            normalization_data["participant_id"].isin(complete_participants)
        ].copy()

    if normalization_data.empty:
        if drop_baseline:
            working = working[working["condition_number"] != baseline_condition].copy()
        return working.reset_index(drop=True)

    for col in available_columns:
        numeric_values = pd.to_numeric(normalization_data[col], errors="coerce")
        participant_means = normalization_data.groupby("participant_id", dropna=False)[col].transform(
            lambda s: pd.to_numeric(s, errors="coerce").mean()
        )
        grand_mean = numeric_values.mean()
        normalized_values = numeric_values - participant_means + grand_mean
        working.loc[normalization_data.index, col] = normalized_values

    morey_factor = np.sqrt(expected_k / (expected_k - 1)) if expected_k > 1 else np.nan
    working.loc[normalization_data.index, NORMALIZED_FLAG_COLUMN] = True
    working.loc[normalization_data.index, MOREY_FACTOR_COLUMN] = morey_factor
    working.loc[normalization_data.index, K_CONDITIONS_COLUMN] = expected_k

    if drop_baseline:
        working = working[working["condition_number"] != baseline_condition].copy()

    return working.reset_index(drop=True)


def normalize_scores_by_participant_baseline(
    data,
    metric_columns,
    treatment_conditions,
    baseline_condition=1,
    drop_baseline=True,
):
    return normalize_scores_cousineau_morey(
        data,
        metric_columns=metric_columns,
        baseline_condition=baseline_condition,
        drop_baseline=drop_baseline,
        normalization_conditions=treatment_conditions,
        require_complete_participants=True,
    )


def extract_condition_number_regex(condition_id):
    if pd.isna(condition_id):
        return np.nan
    match = re.search(r"condition_(\d+)", str(condition_id))
    return int(match.group(1)) if match else np.nan

# %% [markdown]
# ## Experiment 1 preprocessing (from `analysis-0306.ipynb`)

# %%
EXP1_DATA_DIR = Path("Experiment1/data/0306/data")
EXP1_BASELINE_CONDITION_NUMBER = 1
EXP1_COUSINEAU_TREATMENT_K = 3

LIKERT_SOURCE_MIN = 0
LIKERT_SOURCE_MAX = 6
LIKERT_TARGET_MIN = 1
LIKERT_TARGET_MAX = 7


def extract_condition_number_exp1(condition_id):
    if pd.isna(condition_id):
        return np.nan
    for part in str(condition_id).split("_"):
        if part.isdigit():
            return int(part)
    return np.nan


def normalize_likert_scale_0_6_to_1_7(values):
    values = pd.to_numeric(values, errors="coerce")
    valid = values.dropna()
    if valid.empty:
        return values
    if (valid >= LIKERT_SOURCE_MIN).all() and (valid <= LIKERT_SOURCE_MAX).all():
        normalized = values + 1
        return normalized.clip(lower=LIKERT_TARGET_MIN, upper=LIKERT_TARGET_MAX)
    return values


def cousineau_normalize_within_subject_exp1(
    data,
    metric_columns,
    participant_col="participant_id",
    condition_col="condition_number",
    baseline_condition=EXP1_BASELINE_CONDITION_NUMBER,
    k_conditions=EXP1_COUSINEAU_TREATMENT_K,
):
    if data is None:
        return pd.DataFrame()

    if data.empty:
        normalized = data.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = True
        normalized[MOREY_FACTOR_COLUMN] = np.sqrt(k_conditions / (k_conditions - 1)) if k_conditions > 1 else np.nan
        return normalized

    required = {participant_col, condition_col}
    if not required.issubset(data.columns):
        normalized = data.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        return normalized

    available_columns = [col for col in metric_columns if col in data.columns]
    if not available_columns:
        normalized = data.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        return normalized

    working = data.copy()
    working[condition_col] = pd.to_numeric(working[condition_col], errors="coerce")
    working = working[working[condition_col].notna()].copy()

    treatment_only = working[
        (working[condition_col] != baseline_condition)
        & (working[condition_col] != 0)
    ].copy()
    if treatment_only.empty:
        normalized = working.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        return normalized

    participant_condition_counts = (
        treatment_only.groupby(participant_col, dropna=False)[condition_col]
        .nunique()
    )
    complete_participants = participant_condition_counts[
        participant_condition_counts >= k_conditions
    ].index

    normalized = treatment_only[
        treatment_only[participant_col].isin(complete_participants)
    ].copy()

    if normalized.empty:
        normalized = treatment_only.copy()
        normalized[NORMALIZED_FLAG_COLUMN] = False
        normalized[MOREY_FACTOR_COLUMN] = np.nan
        return normalized

    for col in available_columns:
        normalized[col] = pd.to_numeric(normalized[col], errors="coerce")

    participant_means = (
        normalized.groupby(participant_col, dropna=False)[available_columns]
        .transform("mean")
    )
    grand_means = normalized[available_columns].mean()

    normalized[available_columns] = normalized[available_columns] - participant_means + grand_means

    morey_factor = np.sqrt(k_conditions / (k_conditions - 1)) if k_conditions > 1 else np.nan
    normalized[NORMALIZED_FLAG_COLUMN] = True
    normalized[MOREY_FACTOR_COLUMN] = morey_factor

    return normalized.reset_index(drop=True)


def load_experiment1_analysis_data(project_root=PROJECT_ROOT):
    data_dir = project_root / EXP1_DATA_DIR
    csv_files = sorted(data_dir.glob("user_*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No CSV files found in {data_dir}")

    all_data = []
    for file_path in csv_files:
        df = pd.read_csv(file_path)
        df["source_file"] = file_path.name

        if "participant_id" not in df.columns or df["participant_id"].isna().all():
            participant_id = file_path.stem.split("_")[1]
            df["participant_id"] = participant_id

        if "condition_id" in df.columns:
            df["condition_id"] = df["condition_id"].fillna("unknown")
            df["condition_number"] = df["condition_id"].apply(extract_condition_number_exp1)
        else:
            df["condition_id"] = "unknown"
            df["condition_number"] = np.nan

        all_data.append(df)

    combined_data = pd.concat(all_data, ignore_index=True)

    before_participants = combined_data["participant_id"].nunique(dropna=True)
    combined_data = combined_data[combined_data["participant_id"].notna()].copy()
    combined_data = combined_data[~combined_data["participant_id"].astype(str).str.lower().eq("test")].copy()
    after_participants = combined_data["participant_id"].nunique(dropna=True)

    relevant_trial_types = [
        "prediction-task",
        "vis-literacy",
        "trust-survey",
        "personality-survey",
        "survey-text",
        "survey-multi-choice",
    ]
    relevant_trials = combined_data[combined_data["trial_type"].isin(relevant_trial_types)].copy()

    trust_survey_rows = relevant_trials[relevant_trials["trial_type"] == "trust-survey"].copy()
    trust_survey_expanded = expand_response_columns(trust_survey_rows)

    survey_likert_keys = INTERACTION_QUESTION_KEYS + TRUST_QUESTION_KEYS
    for col in survey_likert_keys:
        if col in trust_survey_expanded.columns:
            trust_survey_expanded[col] = normalize_likert_scale_0_6_to_1_7(trust_survey_expanded[col])

    analysis_metric_columns = [col for col in survey_likert_keys if col in trust_survey_expanded.columns]
    analysis_treatment_survey = cousineau_normalize_within_subject_exp1(
        trust_survey_expanded,
        metric_columns=analysis_metric_columns,
        participant_col="participant_id",
        condition_col="condition_number",
        baseline_condition=EXP1_BASELINE_CONDITION_NUMBER,
        k_conditions=EXP1_COUSINEAU_TREATMENT_K,
    )

    print("Experiment 1")
    print(f"  CSV files: {len(csv_files)}")
    print(f"  Participants: {before_participants} -> {after_participants}")
    print(f"  Trust-survey rows: {len(trust_survey_rows)}")
    print(f"  Cousineau-normalized treatment rows: {len(analysis_treatment_survey)}")
    print(f"  Participants retained for normalization: {analysis_treatment_survey['participant_id'].nunique()}")

    return analysis_treatment_survey

# %% [markdown]
# ## Experiment 2 preprocessing (from `0325.ipynb`)

# %%
EXP2_DATA_DIR_CANDIDATES = [
    Path("Experiment2/data/0325/data"),
    Path("Experiment2/data/dist 11/data"),
]
EXP2_BASELINE_CONDITION_NUMBER = 1
EXP2_TREATMENT_CONDITION_NUMBERS = [2, 3, 4, 5, 6, 7, 8, 9, 10]


def load_experiment2_analysis_data(project_root=PROJECT_ROOT):
    data_dir = next((project_root / p for p in EXP2_DATA_DIR_CANDIDATES if (project_root / p).exists()), None)
    if data_dir is None:
        searched = ", ".join(str((project_root / p).resolve()) for p in EXP2_DATA_DIR_CANDIDATES)
        raise FileNotFoundError(f"No Experiment 2 data directory found. Checked: {searched}")

    csv_files = sorted(data_dir.glob("user_*.csv"))
    if not csv_files:
        raise FileNotFoundError(f"No CSV files found in {data_dir.resolve()} using pattern 'user_*.csv'")

    all_data = []
    for file_path in csv_files:
        df = pd.read_csv(file_path)
        df["source_file"] = file_path.name

        if "participant_id" not in df.columns or df["participant_id"].isna().all():
            participant_id = file_path.stem.split("_")[1]
            df["participant_id"] = participant_id

        if "condition_id" not in df.columns:
            df["condition_id"] = np.nan

        df["condition_number"] = df["condition_id"].apply(extract_condition_number_regex)
        all_data.append(df)

    combined_data = pd.concat(all_data, ignore_index=True)

    before_participants = combined_data["participant_id"].nunique(dropna=True)
    combined_data = combined_data[combined_data["participant_id"].notna()].copy()
    combined_data = combined_data[~combined_data["participant_id"].astype(str).str.lower().eq("test")].copy()

    attention_failed_ids, _ = identify_attention_check_failures(combined_data)
    if attention_failed_ids:
        combined_data = combined_data[
            ~combined_data["participant_id"].astype(str).isin(attention_failed_ids)
        ].copy()

    after_participants = combined_data["participant_id"].nunique(dropna=True)

    trust_survey_rows = combined_data[combined_data["trial_type"] == "trust-survey"].copy()
    trust_survey_expanded = ensure_likert_columns(
        trust_survey_rows,
        TRUST_QUESTION_KEYS + INTERACTION_QUESTION_KEYS,
    )

    analysis_metric_columns = [
        col for col in (TRUST_QUESTION_KEYS + INTERACTION_QUESTION_KEYS)
        if col in trust_survey_expanded.columns
    ]

    analysis_trust_survey_expanded = normalize_scores_by_participant_baseline(
        trust_survey_expanded,
        metric_columns=analysis_metric_columns,
        treatment_conditions=EXP2_TREATMENT_CONDITION_NUMBERS,
        baseline_condition=EXP2_BASELINE_CONDITION_NUMBER,
        drop_baseline=False,
    )

    analysis_treatment_survey = analysis_trust_survey_expanded[
        analysis_trust_survey_expanded["condition_number"].isin(EXP2_TREATMENT_CONDITION_NUMBERS)
        & analysis_trust_survey_expanded[NORMALIZED_FLAG_COLUMN].fillna(False)
    ].copy()

    print("Experiment 2")
    print(f"  Data directory: {data_dir.resolve()}")
    print(f"  CSV files: {len(csv_files)}")
    print(f"  Participants: {before_participants} -> {after_participants}")
    print(f"  Attention-check exclusions: {len(attention_failed_ids)}")
    print(f"  Trust-survey rows: {len(trust_survey_rows)}")
    print(f"  Cousineau-normalized treatment rows: {len(analysis_treatment_survey)}")
    print(f"  Participants retained for normalization: {analysis_treatment_survey['participant_id'].nunique()}")

    return analysis_treatment_survey

# %% [markdown]
# ## Experiment 3 preprocessing (from `analysis-0318.ipynb`)

# %%
EXP3_DATA_DIRS = [
    Path("Experiment3/data/0318/data"),
    Path("Experiment3/data/0319/data"),
    Path("Experiment3/data/0322/data"),
]
EXP3_BASELINE_CONDITION_NUMBER = 1
EXP3_TREATMENT_CONDITION_NUMBERS = [21, 22, 23, 24, 25, 26]

EXP3_INTERACTION_CONDITION_LABELS = {
    1: "Baseline",
    21: "Hover Show One",
    22: "Hover Show All",
    23: "Click Show One",
    24: "Click Show All",
    25: "Animation Show One",
    26: "Animation Show All",
}

EXP3_VISUALIZATION_TECHNIQUE_LABELS = {
    "baseline": "Baseline",
    "confidence_interval": "PI",
    "ensemble_plot": "Ensemble",
    "combined_plot": "PI + Ensemble",
}


def map_interaction_group_exp3(condition_number):
    if pd.isna(condition_number):
        return "Other"
    return EXP3_INTERACTION_CONDITION_LABELS.get(int(condition_number), "Other")


def map_visualization_group_exp3(row):
    condition_number = row.get("condition_number", np.nan)
    if pd.notna(condition_number) and int(condition_number) == EXP3_BASELINE_CONDITION_NUMBER:
        return "Baseline"

    technique_raw = str(row.get("visualization_technique", "")).strip().lower()
    if technique_raw in EXP3_VISUALIZATION_TECHNIQUE_LABELS:
        return EXP3_VISUALIZATION_TECHNIQUE_LABELS[technique_raw]

    condition_id = str(row.get("condition_id", "")).strip().lower()
    if condition_id.endswith("_ci"):
        return "PI"
    if condition_id.endswith("_ep"):
        return "Ensemble"
    if condition_id.endswith("_ciep"):
        return "PI + Ensemble"

    condition_name = str(row.get("condition_name", "")).strip().lower()
    if "baseline" in condition_name:
        return "Baseline"
    if "combined" in condition_name:
        return "PI + Ensemble"
    if "ensemble" in condition_name:
        return "Ensemble"
    if "(ci)" in condition_name or "confidence" in condition_name:
        return "PI"

    return "Other"


def load_experiment3_analysis_data(project_root=PROJECT_ROOT):
    csv_files_by_dir = {
        (project_root / data_dir): sorted((project_root / data_dir).glob("user_*.csv"))
        for data_dir in EXP3_DATA_DIRS
    }
    csv_files = [file_path for files in csv_files_by_dir.values() for file_path in files]

    if not csv_files:
        searched_dirs = ", ".join(str((project_root / path).resolve()) for path in EXP3_DATA_DIRS)
        raise FileNotFoundError(f"No CSV files found in [{searched_dirs}] using pattern 'user_*.csv'")

    all_data = []
    for data_dir, files in csv_files_by_dir.items():
        batch_label = data_dir.parent.name
        for file_path in files:
            df = pd.read_csv(file_path)
            df["source_file"] = file_path.name

            if "participant_id" not in df.columns or df["participant_id"].isna().all():
                participant_id = file_path.stem.split("_")[1]
                df["participant_id"] = participant_id

            if "condition_id" not in df.columns:
                df["condition_id"] = np.nan
            if "condition_name" not in df.columns:
                df["condition_name"] = np.nan

            df["condition_number"] = df["condition_id"].apply(extract_condition_number_regex)
            df["interaction_group"] = df["condition_number"].apply(map_interaction_group_exp3)
            df["visualization_group"] = df.apply(map_visualization_group_exp3, axis=1)
            df["data_batch"] = batch_label
            all_data.append(df)

    combined_data = pd.concat(all_data, ignore_index=True)

    before_participants = combined_data["participant_id"].nunique(dropna=True)
    combined_data = combined_data[combined_data["participant_id"].notna()].copy()
    combined_data = combined_data[~combined_data["participant_id"].astype(str).str.lower().eq("test")].copy()

    attention_failed_ids, _ = identify_attention_check_failures(combined_data)
    if attention_failed_ids:
        combined_data = combined_data[
            ~combined_data["participant_id"].astype(str).isin(attention_failed_ids)
        ].copy()

    after_participants = combined_data["participant_id"].nunique(dropna=True)

    relevant_trial_types = [
        "prediction-task",
        "vis-literacy",
        "trust-survey",
        "interaction-feedback",
        "personality-survey",
        "survey-text",
        "survey-multi-choice",
    ]

    relevant_trials = combined_data[combined_data["trial_type"].isin(relevant_trial_types)].copy()

    trust_survey_rows = relevant_trials[relevant_trials["trial_type"] == "trust-survey"].copy()
    trust_survey_expanded = ensure_likert_columns(
        trust_survey_rows,
        TRUST_QUESTION_KEYS + INTERACTION_QUESTION_KEYS,
    )

    analysis_metric_columns = [
        col for col in (TRUST_QUESTION_KEYS + INTERACTION_QUESTION_KEYS)
        if col in trust_survey_expanded.columns
    ]

    analysis_trust_survey_expanded = normalize_scores_by_participant_baseline(
        trust_survey_expanded,
        metric_columns=analysis_metric_columns,
        treatment_conditions=EXP3_TREATMENT_CONDITION_NUMBERS,
        baseline_condition=EXP3_BASELINE_CONDITION_NUMBER,
        drop_baseline=False,
    )

    analysis_treatment_survey = analysis_trust_survey_expanded[
        analysis_trust_survey_expanded["condition_number"].isin(EXP3_TREATMENT_CONDITION_NUMBERS)
        & analysis_trust_survey_expanded[NORMALIZED_FLAG_COLUMN].fillna(False)
    ].copy()

    print("Experiment 3")
    for data_dir, files in csv_files_by_dir.items():
        print(f"  Data directory: {data_dir.resolve()} ({len(files)} files)")
    print(f"  CSV files: {len(csv_files)}")
    print(f"  Participants: {before_participants} -> {after_participants}")
    print(f"  Attention-check exclusions: {len(attention_failed_ids)}")
    print(f"  Trust-survey rows: {len(trust_survey_rows)}")
    print(f"  Cousineau-normalized treatment rows: {len(analysis_treatment_survey)}")
    print(f"  Participants retained for normalization: {analysis_treatment_survey['participant_id'].nunique()}")

    return analysis_treatment_survey

# %% [markdown]
# ## Load, preprocess, and pool analysis tables

# %%
exp1_analysis_data = load_experiment1_analysis_data()
exp2_analysis_data = load_experiment2_analysis_data()
exp3_analysis_data = load_experiment3_analysis_data()

individual_experiment_data = {
    "Experiment 1 (0306)": exp1_analysis_data,
    "Experiment 2 (0325)": exp2_analysis_data,
    "Experiment 3 (0318/0319/0322)": exp3_analysis_data,
}

pooled_frames = []
for exp_name, df in individual_experiment_data.items():
    tagged = df.copy()
    tagged["source_experiment"] = exp_name

    if "participant_id" in tagged.columns:
        tagged["pooled_participant_id"] = (
            tagged["source_experiment"].astype(str) + "::" + tagged["participant_id"].astype(str)
        )
    else:
        tagged["pooled_participant_id"] = np.nan

    pooled_frames.append(tagged)

pooled_analysis_data = pd.concat(pooled_frames, ignore_index=True, sort=False)

experiment_data = {
    "Pooled Exp1+Exp2+Exp3": pooled_analysis_data,
}

summary_rows = []
for exp_name, df in individual_experiment_data.items():
    summary_rows.append(
        {
            "dataset": exp_name,
            "rows": len(df),
            "participants": df["participant_id"].nunique() if "participant_id" in df.columns else np.nan,
            "trust_complete_rows": df[TRUST_QUESTION_KEYS].notna().all(axis=1).sum() if set(TRUST_QUESTION_KEYS).issubset(df.columns) else np.nan,
            "interaction_complete_rows": df[INTERACTION_QUESTION_KEYS].notna().all(axis=1).sum() if set(INTERACTION_QUESTION_KEYS).issubset(df.columns) else np.nan,
        }
    )

summary_rows.append(
    {
        "dataset": "Pooled Exp1+Exp2+Exp3",
        "rows": len(pooled_analysis_data),
        "participants": pooled_analysis_data["pooled_participant_id"].nunique() if "pooled_participant_id" in pooled_analysis_data.columns else np.nan,
        "trust_complete_rows": pooled_analysis_data[TRUST_QUESTION_KEYS].notna().all(axis=1).sum() if set(TRUST_QUESTION_KEYS).issubset(pooled_analysis_data.columns) else np.nan,
        "interaction_complete_rows": pooled_analysis_data[INTERACTION_QUESTION_KEYS].notna().all(axis=1).sum() if set(INTERACTION_QUESTION_KEYS).issubset(pooled_analysis_data.columns) else np.nan,
    }
)

summary_df = pd.DataFrame(summary_rows)
display(summary_df)
# Out:
# Experiment 1
#   CSV files: 337
#   Participants: 337 -> 337
#   Trust-survey rows: 1340
#   Cousineau-normalized treatment rows: 1005
#   Participants retained for normalization: 335
# Experiment 2
#   Data directory: /Users/songwen/Documents/Code Lab/Interact4Trust/Experiment2/data/0325/data
#   CSV files: 91
#   Participants: 91 -> 87
#   Attention-check exclusions: 4
#   Trust-survey rows: 870
#   Cousineau-normalized treatment rows: 783
#   Participants retained for normalization: 87
# Experiment 3
#   Data directory: /Users/songwen/Documents/Code Lab/Interact4Trust/Experiment3/data/0318/data (27 files)
#   Data directory: /Users/songwen/Documents/Code Lab/Interact4Trust/Experiment3/data/0319/data (57 files)
#   Data directory: /Users/songwen/Documents/Code Lab/Interact4Trust/Experiment3/data/0322/data (58 files)
#   CSV files: 142
#   Participants: 142 -> 140
#   Attention-check exclusions: 2
#   Trust-survey rows: 980
#   Cousineau-normalized treatment rows: 840
#   Participants retained for normalization: 140
#                          dataset  rows  participants  trust_complete_rows  \
# 0            Experiment 1 (0306)  1005           335                 1005
# 1            Experiment 2 (0325)   783            87                  783
# 2  Experiment 3 (0318/0319/0322)   840           140                  840
# 3          Pooled Exp1+Exp2+Exp3  2628           562                 2628
#
#    interaction_complete_rows
# 0                       1005
# 1                        783
# 2                        840
# 3                       2628

# %% [markdown]
# ## Fixed factor analyses on pooled data (Trust: 1-4 factors, Interaction: 1-9 factors)

# %%
def prepare_factor_rows(data, question_keys, section_label):
    if data is None or data.empty:
        print(f"[skip] {section_label}: no rows available.")
        return pd.DataFrame()

    available_keys = [k for k in question_keys if k in data.columns]
    if len(available_keys) < 2:
        print(f"[skip] {section_label}: fewer than 2 usable columns.")
        return pd.DataFrame()

    analysis_rows = data[available_keys].apply(pd.to_numeric, errors="coerce").dropna()

    if analysis_rows.shape[0] < 10 or analysis_rows.shape[1] < 2:
        print(
            f"[skip] {section_label}: insufficient complete rows/columns "
            f"(n={analysis_rows.shape[0]}, p={analysis_rows.shape[1]})."
        )
        return pd.DataFrame()

    constant_columns = [col for col in analysis_rows.columns if analysis_rows[col].nunique(dropna=True) <= 1]
    if constant_columns:
        analysis_rows = analysis_rows.drop(columns=constant_columns)
        print(f"[note] {section_label}: dropped constant columns: {', '.join(constant_columns)}")

    if analysis_rows.shape[1] < 2:
        print(f"[skip] {section_label}: too few non-constant columns.")
        return pd.DataFrame()

    return analysis_rows


def _compute_factor_model_metrics(fa, analysis_rows, loading_matrix, factor_correlation=None):
    n_samples, n_features = analysis_rows.shape
    n_factors = fa.n_components

    # Approximate free-parameter count retained from the original notebook for continuity.
    # k = p*m + p - m(m-1)/2, where p is variables and m is factors.
    n_parameters = (n_features * n_factors) + n_features - (n_factors * (n_factors - 1) / 2)

    X = analysis_rows.to_numpy()
    log_likelihood = fa.score(X) * n_samples
    aic = (2 * n_parameters) - (2 * log_likelihood)
    bic = (np.log(n_samples) * n_parameters) - (2 * log_likelihood)

    communalities = (loading_matrix**2).sum(axis=1)
    mean_communality = communalities.mean()

    total_variance = analysis_rows.var(axis=0, ddof=0).sum()
    common_variance = communalities.sum()
    variance_explained = np.nan if total_variance <= 0 else (common_variance / total_variance)

    # Root Mean Residual from off-diagonal residuals of observed vs model-implied correlations.
    observed_corr = np.corrcoef(X, rowvar=False)
    loading_values = loading_matrix.to_numpy()
    if factor_correlation is None:
        factor_covariance = np.eye(loading_values.shape[1])
    else:
        factor_covariance = np.asarray(factor_correlation, dtype=float)
    model_cov = loading_values @ factor_covariance @ loading_values.T + np.diag(fa.noise_variance_)
    model_sd = np.sqrt(np.clip(np.diag(model_cov), a_min=1e-12, a_max=None))
    model_corr = model_cov / np.outer(model_sd, model_sd)
    residual_matrix = observed_corr - model_corr
    upper_tri = np.triu_indices_from(residual_matrix, k=1)
    off_diag_residuals = residual_matrix[upper_tri]
    root_mean_residual = np.sqrt(np.mean(off_diag_residuals**2)) if off_diag_residuals.size else np.nan

    metrics = {
        "AIC": aic,
        "BIC": bic,
        "Root Mean Residual": root_mean_residual,
        "Mean Communality": mean_communality,
        "Variance Explained": variance_explained,
    }

    return metrics, communalities


def _oblimin_objective(loadings, gamma=0.0):
    n_rows, n_cols = loadings.shape
    off_diag_selector = np.ones((n_cols, n_cols)) - np.eye(n_cols)
    term = (loadings**2) @ off_diag_selector
    if gamma != 0:
        row_centering = (np.ones((n_rows, n_rows)) - np.eye(n_rows)) / n_rows
        term = term - gamma * (row_centering @ (loadings**2))
    gradient = loadings * term
    criterion = np.sum((loadings**2) * term) / 4
    return {"grad": gradient, "criterion": criterion}


def _oblique_rotate_oblimin(loadings, gamma=0.0, max_iter=OBLIMIN_MAX_ITER, tol=OBLIMIN_TOL):
    n_cols = loadings.shape[1]
    if n_cols < 2:
        identity = np.eye(n_cols)
        return loadings.copy(), identity, identity

    rotation_matrix = np.eye(n_cols)
    new_rotation_matrix = rotation_matrix.copy()
    alpha = 1.0
    rotation_matrix_inv = np.linalg.inv(rotation_matrix)
    new_loadings = loadings @ rotation_matrix_inv.T

    obj = _oblimin_objective(new_loadings, gamma=gamma)
    gradient = -(new_loadings.T @ (obj["grad"] @ rotation_matrix_inv)).T
    criterion = obj["criterion"]
    obj_t = obj

    for _ in range(max_iter + 1):
        gradient_new = gradient - rotation_matrix @ np.diag(
            np.ones(gradient.shape[0]) @ (rotation_matrix * gradient)
        )
        s = np.sqrt(np.sum(np.diag(gradient_new.T @ gradient_new)))

        if s < tol:
            break

        alpha = 2 * alpha

        for _ in range(11):
            X = rotation_matrix - alpha * gradient_new
            v = 1 / np.sqrt(np.ones(X.shape[0]) @ (X**2))
            new_rotation_matrix = X @ np.diag(v)
            new_loadings = loadings @ np.linalg.inv(new_rotation_matrix).T
            obj_t = _oblimin_objective(new_loadings, gamma=gamma)
            improvement = criterion - obj_t["criterion"]

            if improvement > 0.5 * (s**2) * alpha:
                break

            alpha = alpha / 2

        rotation_matrix = new_rotation_matrix
        criterion = obj_t["criterion"]
        gradient = -((new_loadings.T @ obj_t["grad"]) @ np.linalg.inv(new_rotation_matrix)).T

    phi = rotation_matrix.T @ rotation_matrix
    return new_loadings.copy(), rotation_matrix, phi


def apply_oblimin_with_kaiser(
    loadings,
    gamma=OBLIMIN_GAMMA,
    max_iter=OBLIMIN_MAX_ITER,
    tol=OBLIMIN_TOL,
    normalize=OBLIMIN_KAISER_NORMALIZE,
):
    raw_loadings = np.asarray(loadings, dtype=float)
    if raw_loadings.ndim != 2:
        raise ValueError("Loadings must be a 2D array.")

    if raw_loadings.shape[1] < 2:
        identity = np.eye(raw_loadings.shape[1])
        return raw_loadings.copy(), identity, identity

    if normalize:
        row_norms = np.sqrt(np.sum(raw_loadings**2, axis=1))
        row_norms = np.where(row_norms <= 1e-12, 1.0, row_norms)
        working_loadings = raw_loadings / row_norms[:, None]
    else:
        row_norms = np.ones(raw_loadings.shape[0], dtype=float)
        working_loadings = raw_loadings.copy()

    rotated_working, rotation_matrix, phi = _oblique_rotate_oblimin(
        working_loadings,
        gamma=gamma,
        max_iter=max_iter,
        tol=tol,
    )

    if normalize:
        rotated_loadings = rotated_working * row_norms[:, None]
    else:
        rotated_loadings = rotated_working

    return rotated_loadings, rotation_matrix, phi


def run_fixed_factor_analysis(
    data,
    question_keys,
    section_label,
    n_factors,
    threshold=LOADING_THRESHOLD,
    prompt_map=None,
):
    analysis_rows = prepare_factor_rows(data, question_keys, section_label)
    if analysis_rows.empty:
        return {}

    max_components = min(analysis_rows.shape[1], analysis_rows.shape[0] - 1)
    if n_factors > max_components:
        print(
            f"[skip] {section_label} ({n_factors} factors): requested components exceed "
            f"max allowable ({max_components})."
        )
        return {}

    fa = FactorAnalysis(n_components=n_factors, random_state=42)
    factor_scores = fa.fit_transform(analysis_rows)

    factor_cols = [f"Factor {i + 1}" for i in range(n_factors)]
    rotated_loadings, rotation_matrix, factor_phi = apply_oblimin_with_kaiser(
        fa.components_.T,
        gamma=OBLIMIN_GAMMA,
        max_iter=OBLIMIN_MAX_ITER,
        tol=OBLIMIN_TOL,
        normalize=OBLIMIN_KAISER_NORMALIZE,
    )

    loading_matrix = pd.DataFrame(
        rotated_loadings,
        index=analysis_rows.columns,
        columns=factor_cols,
    )
    factor_correlation = pd.DataFrame(
        factor_phi,
        index=factor_cols,
        columns=factor_cols,
    )
    rotated_scores = factor_scores @ rotation_matrix

    metrics, communalities = _compute_factor_model_metrics(
        fa,
        analysis_rows,
        loading_matrix,
        factor_correlation=factor_phi,
    )

    if isinstance(prompt_map, dict) and prompt_map:
        loading_matrix.index = [prompt_map.get(k, k) for k in loading_matrix.index]
        communalities.index = loading_matrix.index

    print()
    print(f"=== {section_label} | {n_factors} factor(s) ===")
    print(f"Rows used: {len(analysis_rows)}")
    print(f"Variables tested: {analysis_rows.shape[1]}")
    print(
        "Metrics -> "
        f"AIC: {metrics['AIC']:.2f}, "
        f"BIC: {metrics['BIC']:.2f}, "
        f"RMR: {metrics['Root Mean Residual']:.3f}, "
        f"Mean communality: {metrics['Mean Communality']:.3f}, "
        f"Variance explained: {metrics['Variance Explained']:.3f}"
    )
    if n_factors == 3:
        print("Factor correlation matrix (Oblimin with Kaiser normalization):")
        print(factor_correlation.round(3).to_string())

    filtered_table = loading_matrix.where(loading_matrix.abs() >= threshold)
    filtered_table["max_abs_loading"] = loading_matrix.abs().max(axis=1)
    filtered_table = filtered_table[filtered_table[factor_cols].notna().any(axis=1)]
    filtered_table = filtered_table.sort_values("max_abs_loading", ascending=False)

    return {
        "n_factors": n_factors,
        "loadings": loading_matrix,
        "filtered_loadings": filtered_table,
        "scores": pd.DataFrame(rotated_scores, columns=factor_cols),
        "analysis_rows": analysis_rows,
        "metrics": metrics,
        "communalities": communalities,
        "rotation": "oblimin_kaiser",
        "rotation_matrix": pd.DataFrame(rotation_matrix, index=factor_cols, columns=factor_cols),
        "factor_correlation": factor_correlation,
    }


def run_factor_suite_for_experiment(experiment_label, data):
    print("\n" + "=" * 100)
    print(f"{experiment_label}")

    results = {}

    for n_factors in TRUST_FACTOR_COUNTS:
        results[f"trust_{n_factors}f"] = run_fixed_factor_analysis(
            data,
            TRUST_QUESTION_KEYS,
            section_label=f"{experiment_label} - Trust / Usability block",
            n_factors=n_factors,
            threshold=LOADING_THRESHOLD,
            prompt_map=TRUST_PROMPT_MAP,
        )

    for n_factors in INTERACTION_FACTOR_COUNTS:
        results[f"interaction_{n_factors}f"] = run_fixed_factor_analysis(
            data,
            INTERACTION_QUESTION_KEYS,
            section_label=f"{experiment_label} - Interaction block",
            n_factors=n_factors,
            threshold=LOADING_THRESHOLD,
            prompt_map=INTERACTION_PROMPT_MAP,
        )

    return results


def _experiment_short_label(experiment_name):
    match = re.search(r"Experiment\s*(\d+)", str(experiment_name))
    if match:
        return f"Exp{match.group(1)}"
    return str(experiment_name)


def _factor_model_label(n_factors):
    return f"{n_factors}-factor"


def build_combined_loading_table(all_factor_results, threshold=LOADING_THRESHOLD, factor_counts=None):
    selected_factor_counts = sorted(set(FACTOR_COUNTS if factor_counts is None else factor_counts))

    row_index = [
        *[f"Trust | {TRUST_PROMPT_MAP.get(k, k)}" for k in TRUST_QUESTION_KEYS],
        *[f"Interaction | {INTERACTION_PROMPT_MAP.get(k, k)}" for k in INTERACTION_QUESTION_KEYS],
    ]

    factor_labels_by_model = {
        n_factors: [f"factor{i}" for i in range(1, n_factors + 1)]
        for n_factors in selected_factor_counts
    }

    experiment_labels = [_experiment_short_label(name) for name in all_factor_results.keys()]
    column_tuples = [
        (exp_label, _factor_model_label(n_factors), factor_label)
        for exp_label in experiment_labels
        for n_factors in selected_factor_counts
        for factor_label in factor_labels_by_model.get(n_factors, [])
    ]

    columns = pd.MultiIndex.from_tuples(
        column_tuples,
        names=["Experiment", "Factor Model", "Factor"],
    )

    combined_table = pd.DataFrame(np.nan, index=row_index, columns=columns, dtype=float)

    for experiment_name, experiment_results in all_factor_results.items():
        exp_label = _experiment_short_label(experiment_name)

        for block_name, block_label in [("trust", "Trust"), ("interaction", "Interaction")]:
            for n_factors in selected_factor_counts:
                result_key = f"{block_name}_{n_factors}f"
                result = experiment_results.get(result_key, {})
                loading_matrix = result.get("loadings") if isinstance(result, dict) else None

                if not isinstance(loading_matrix, pd.DataFrame) or loading_matrix.empty:
                    continue

                for factor_idx, factor_col in enumerate(loading_matrix.columns, start=1):
                    target_column = (
                        exp_label,
                        _factor_model_label(n_factors),
                        f"factor{factor_idx}",
                    )
                    if target_column not in combined_table.columns:
                        continue

                    for question_text, loading_value in loading_matrix[factor_col].items():
                        target_row = f"{block_label} | {question_text}"
                        if target_row in combined_table.index:
                            combined_table.loc[target_row, target_column] = loading_value

    return combined_table


def build_factor_metrics_table(all_factor_results):
    metric_rows = []

    for experiment_name, experiment_results in all_factor_results.items():
        exp_label = _experiment_short_label(experiment_name)
        block_factor_specs = [
            ("trust", "Trust", TRUST_FACTOR_COUNTS),
            ("interaction", "Interaction", INTERACTION_METRIC_FACTOR_COUNTS),
        ]

        for block_name, block_label, factor_counts in block_factor_specs:
            for n_factors in factor_counts:
                result_key = f"{block_name}_{n_factors}f"
                result = experiment_results.get(result_key, {})
                metrics = result.get("metrics") if isinstance(result, dict) else None

                if not isinstance(metrics, dict) or not metrics:
                    continue

                metric_rows.append(
                    {
                        "Experiment": exp_label,
                        "Block": block_label,
                        "Factor Model": _factor_model_label(n_factors),
                        "AIC": metrics.get("AIC", np.nan),
                        "BIC": metrics.get("BIC", np.nan),
                        "Root Mean Residual": metrics.get("Root Mean Residual", np.nan),
                        "Mean Communality": metrics.get("Mean Communality", np.nan),
                        "Variance Explained": metrics.get("Variance Explained", np.nan),
                    }
                )

    metrics_table = pd.DataFrame(metric_rows)
    if metrics_table.empty:
        return metrics_table

    factor_order = {f"{i}-factor": i for i in FACTOR_COUNTS}
    metrics_table["_factor_order"] = metrics_table["Factor Model"].map(factor_order)
    metrics_table = metrics_table.sort_values(["Experiment", "Block", "_factor_order"])
    metrics_table = metrics_table.drop(columns=["_factor_order"])

    return metrics_table.reset_index(drop=True)


def style_loading_table_with_threshold(loading_df, threshold=LOADING_THRESHOLD, decimals=3):
    if loading_df.empty:
        return loading_df.style

    highlight_mask = loading_df > threshold

    def _highlight(_):
        return highlight_mask.replace({True: "font-weight: bold", False: ""})

    return loading_df.style.apply(_highlight, axis=None).format(
        lambda value: "" if pd.isna(value) else f"{value:.{decimals}f}"
    )


def _format_loading_value_for_latex(value, threshold=LOADING_THRESHOLD, decimals=3):
    if pd.isna(value):
        return ""

    formatted_value = f"{value:.{decimals}f}"
    if value > threshold:
        return f"\\textbf{{{formatted_value}}}"
    return formatted_value


def export_combined_table_to_latex(combined_table, output_path="factor.tex", decimals=3, threshold=LOADING_THRESHOLD):
    formatted = pd.DataFrame("", index=combined_table.index, columns=combined_table.columns, dtype=object)

    for column in combined_table.columns:
        for row_label, value in combined_table[column].items():
            formatted.loc[row_label, column] = _format_loading_value_for_latex(
                value,
                threshold=threshold,
                decimals=decimals,
            )

    latex = formatted.to_latex(
        na_rep="",
        multicolumn=True,
        multirow=True,
        longtable=True,
        escape=False,
    )
    output_file = Path(output_path)
    output_file.write_text(latex)
    return output_file

# %%
all_factor_results = {}
for exp_name, df in experiment_data.items():
    all_factor_results[exp_name] = run_factor_suite_for_experiment(exp_name, df)

combined_factor_loading_table = build_combined_loading_table(
    all_factor_results,
    threshold=LOADING_THRESHOLD,
    factor_counts=LOADING_TABLE_FACTOR_COUNTS,
)
interaction_row_prefix = "Interaction | "
combined_factor_loading_table = combined_factor_loading_table.loc[
    [row for row in combined_factor_loading_table.index if row.startswith(interaction_row_prefix)]
].copy()
combined_factor_loading_table.index = combined_factor_loading_table.index.str.replace(
    rf"^{re.escape(interaction_row_prefix)}",
    "",
    regex=True,
)
print("\nInteraction question factor-loading table (3-factor only, pooled data)")
display(style_loading_table_with_threshold(combined_factor_loading_table, threshold=LOADING_THRESHOLD, decimals=3))

factor_metrics_table = build_factor_metrics_table(all_factor_results)
trust_factor_metrics_table = pd.DataFrame()
interaction_factor_metrics_table = pd.DataFrame()

METRIC_COLUMNS = ["AIC", "BIC", "Root Mean Residual", "Mean Communality", "Variance Explained"]

METRIC_RULES = {
    "AIC": "min",
    "BIC": "min",
    "Root Mean Residual": "min",
    "Mean Communality": "max",
    "Variance Explained": "max",
}


def _experiment_display_label(exp_label):
    match = re.search(r"Exp\s*(\d+)", str(exp_label))
    if match:
        return f"Experiment {match.group(1)}"
    return str(exp_label)


def build_block_metrics_pivot(metrics_df, block_label):
    block_df = metrics_df.loc[metrics_df["Block"] == block_label].copy()
    if block_df.empty:
        return block_df

    block_df["Experiment"] = block_df["Experiment"].map(_experiment_display_label)
    block_df["Factor Number"] = pd.to_numeric(
        block_df["Factor Model"].astype(str).str.extract(r"(\d+)")[0],
        errors="coerce",
    )
    block_df = block_df.dropna(subset=["Factor Number"])
    block_df["Factor Number"] = block_df["Factor Number"].astype(int)
    block_df["Factor Model"] = block_df["Factor Number"].map(_factor_model_label)

    if block_label == "Trust":
        factor_counts = TRUST_FACTOR_COUNTS
    elif block_label == "Interaction":
        factor_counts = INTERACTION_METRIC_FACTOR_COUNTS
    else:
        factor_counts = FACTOR_COUNTS

    factor_index = [_factor_model_label(i) for i in factor_counts]

    experiment_order = sorted(
        block_df["Experiment"].dropna().unique(),
        key=lambda label: int(re.search(r"(\d+)", str(label)).group(1))
        if re.search(r"(\d+)", str(label))
        else str(label),
    )

    pivot = block_df.pivot_table(
        index="Factor Model",
        columns="Experiment",
        values=METRIC_COLUMNS,
        aggfunc="first",
    )

    if isinstance(pivot.columns, pd.MultiIndex):
        pivot = pivot.swaplevel(0, 1, axis=1)

    target_columns = pd.MultiIndex.from_product(
        [experiment_order, METRIC_COLUMNS],
        names=["Experiment", "Metric"],
    )

    pivot = pivot.reindex(index=factor_index)
    pivot = pivot.reindex(columns=target_columns)
    pivot.index.name = "Factor Model"

    return pivot


def _metric_name_from_column(column):
    return column[1] if isinstance(column, tuple) else column


def _metric_format_rules(metrics_df):
    format_rules = {}
    for column in metrics_df.columns:
        metric_name = _metric_name_from_column(column)
        if metric_name in {"AIC", "BIC"}:
            format_rules[column] = "{:.2f}"
        elif metric_name in {"Root Mean Residual", "Mean Communality"}:
            format_rules[column] = "{:.3f}"
        elif metric_name == "Variance Explained":
            format_rules[column] = "{:.2f}%"
    return format_rules


def _best_metric_mask(metrics_df):
    styles = pd.DataFrame(False, index=metrics_df.index, columns=metrics_df.columns)

    if metrics_df.empty or not isinstance(metrics_df.columns, pd.MultiIndex):
        return styles

    for experiment in metrics_df.columns.get_level_values(0).unique():
        for metric_col, rule in METRIC_RULES.items():
            target_column = (experiment, metric_col)
            if target_column not in metrics_df.columns:
                continue

            series = metrics_df[target_column].dropna()
            if series.empty:
                continue

            target_value = series.min() if rule == "min" else series.max()
            best_rows = series[series == target_value].index
            styles.loc[best_rows, target_column] = True

    return styles


def style_pivot_metrics_with_best(metrics_df):
    if metrics_df.empty:
        return metrics_df.style

    best_mask = _best_metric_mask(metrics_df)

    def _highlight_best(_):
        return best_mask.replace({True: "font-weight: bold", False: ""})

    return metrics_df.style.apply(_highlight_best, axis=None).format(_metric_format_rules(metrics_df))


def _format_metric_value_for_latex(metric_name, value):
    if pd.isna(value):
        return ""

    if metric_name in {"AIC", "BIC"}:
        return f"{value:.2f}"
    if metric_name in {"Root Mean Residual", "Mean Communality"}:
        return f"{value:.3f}"
    if metric_name == "Variance Explained":
        return f"{value:.2f}\\%"
    return str(value)


def export_metrics_table_to_latex(metrics_df, output_path, caption=None, label=None):
    output_file = Path(output_path)

    if metrics_df.empty:
        output_file.write_text("")
        return output_file

    best_mask = _best_metric_mask(metrics_df)
    formatted = pd.DataFrame("", index=metrics_df.index, columns=metrics_df.columns, dtype=object)

    for column in metrics_df.columns:
        metric_name = _metric_name_from_column(column)
        for row_label, value in metrics_df[column].items():
            formatted_value = _format_metric_value_for_latex(metric_name, value)
            if formatted_value and bool(best_mask.loc[row_label, column]):
                formatted_value = f"\\textbf{{{formatted_value}}}"
            formatted.loc[row_label, column] = formatted_value

    latex = formatted.to_latex(
        na_rep="",
        multicolumn=True,
        multirow=True,
        escape=False,
        caption=caption,
        label=label,
    )
    output_file.write_text(latex)
    return output_file


def plot_interaction_metric_lines(metrics_df, output_dir="analysis_outputs"):
    if metrics_df.empty:
        return {}

    plot_df = metrics_df.loc[
        metrics_df["Block"] == "Interaction",
        ["Experiment", "Factor Model", "BIC", "Root Mean Residual"],
    ].copy()
    if plot_df.empty:
        return {}

    plot_df["Factor Number"] = pd.to_numeric(
        plot_df["Factor Model"].astype(str).str.extract(r"(\d+)")[0],
        errors="coerce",
    )
    plot_df = plot_df.dropna(subset=["Factor Number"])
    plot_df["Factor Number"] = plot_df["Factor Number"].astype(int)
    plot_df = plot_df[plot_df["Factor Number"].isin(INTERACTION_METRIC_FACTOR_COUNTS)]
    plot_df = plot_df.sort_values(["Experiment", "Factor Number"])
    plot_df["Normalized BIC"] = plot_df["BIC"] - plot_df.groupby("Experiment")["BIC"].transform("min")
    if plot_df.empty:
        return {}

    experiment_order = sorted(
        plot_df["Experiment"].dropna().unique(),
        key=lambda label: int(re.search(r"(\d+)", str(label)).group(1))
        if re.search(r"(\d+)", str(label))
        else str(label),
    )

    output_folder = Path(output_dir)
    output_folder.mkdir(parents=True, exist_ok=True)

    metric_outputs = {
        "BIC": output_folder / "interaction-factor-bic.png",
        "Normalized BIC": output_folder / "interaction-factor-bic-normalized.png",
        "Root Mean Residual": output_folder / "interaction-factor-rmr.png",
    }

    for metric_name, output_file in metric_outputs.items():
        fig, axis = plt.subplots(figsize=(7, 5))
        for experiment in experiment_order:
            subset = plot_df.loc[plot_df["Experiment"] == experiment]
            axis.plot(
                subset["Factor Number"],
                subset[metric_name],
                marker="o",
                linewidth=1.8,
                color="black",
            )

        axis.set_xlabel("Number of factors", fontsize=14)
        if metric_name == "Normalized BIC":
            axis.set_ylabel("BIC - min(BIC, factors 1-8)", fontsize=14)
            axis.set_title("Interaction experience: Normalized BIC", fontsize=14)
        else:
            axis.set_ylabel(metric_name, fontsize=14)
            axis.set_title(f"Interaction experience: {metric_name}", fontsize=14)
        axis.set_xticks(INTERACTION_METRIC_FACTOR_COUNTS)
        axis.tick_params(axis="both", labelsize=12)
        axis.grid(False)

        fig.tight_layout()
        plt.show()
        fig.savefig(output_file, format="png", dpi=300, bbox_inches="tight")
        plt.close(fig)

    return metric_outputs


if factor_metrics_table.empty:
    print("\nNo factor-model metrics were produced.")
else:
    metrics_display = factor_metrics_table.copy()
    metrics_display["Variance Explained"] = metrics_display["Variance Explained"] * 100

    trust_factor_metrics_table = build_block_metrics_pivot(metrics_display, "Trust")
    interaction_factor_metrics_table = build_block_metrics_pivot(metrics_display, "Interaction")

    print("\nTrust factor-model metrics table (AIC, BIC, root mean residual, mean communality, variance explained)")
    display(style_pivot_metrics_with_best(trust_factor_metrics_table))

    print("\nInteraction experience factor-model metrics table (AIC, BIC, root mean residual, mean communality, variance explained)")
    display(style_pivot_metrics_with_best(interaction_factor_metrics_table))

    interaction_plot_paths = plot_interaction_metric_lines(
        factor_metrics_table,
        output_dir="analysis_outputs/pooled",
    )
    if interaction_plot_paths:
        for metric_name, plot_path in interaction_plot_paths.items():
            print(f"Interaction metric trend figure ({metric_name}) written to: {plot_path.resolve()}")

    interaction_metrics_latex_path = export_metrics_table_to_latex(
        interaction_factor_metrics_table,
        output_path="interaction-factor-metrics-pooled.tex",
        caption="Pooled interaction experience factor-model metrics (AIC, BIC, root mean residual, mean communality, variance explained).",
        label="tab:pooled_interaction_factor_metrics",
    )
    print(f"Interaction metrics LaTeX table written to: {interaction_metrics_latex_path.resolve()}")

latex_output_path = export_combined_table_to_latex(
    combined_factor_loading_table,
    output_path="factor-pooled.tex",
    decimals=3,
    threshold=LOADING_THRESHOLD,
)
print(f"LaTeX table written to: {latex_output_path.resolve()}")
# Out:
# ====================================================================================================
# Pooled Exp1+Exp2+Exp3
#
# === Pooled Exp1+Exp2+Exp3 - Trust / Usability block | 1 factor(s) ===
# Rows used: 2628
# Variables tested: 4
# Metrics -> AIC: 26198.48, BIC: 26245.47, RMR: 0.093, Mean communality: 0.496, Variance explained: 0.508
#
# === Pooled Exp1+Exp2+Exp3 - Trust / Usability block | 2 factor(s) ===
# Rows used: 2628
# Variables tested: 4
# Metrics -> AIC: 25825.80, BIC: 25890.41, RMR: 0.008, Mean communality: 0.600, Variance explained: 0.615
#
# === Pooled Exp1+Exp2+Exp3 - Trust / Usability block | 3 factor(s) ===
# Rows used: 2628
# Variables tested: 4
# Metrics -> AIC: 25823.85, BIC: 25900.21, RMR: 0.000, Mean communality: 0.610, Variance explained: 0.625
# Factor correlation matrix (Oblimin with Kaiser normalization):
#           Factor 1  Factor 2  Factor 3
# Factor 1     1.000     0.668    -0.041
# Factor 2     0.668     1.000    -0.054
# Factor 3    -0.041    -0.054     1.000
#
# === Pooled Exp1+Exp2+Exp3 - Trust / Usability block | 4 factor(s) ===
# Rows used: 2628
# Variables tested: 4
# Metrics -> AIC: 26364.58, BIC: 26446.82, RMR: 0.111, Mean communality: 0.484, Variance explained: 0.496
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 1 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 54513.89, BIC: 54619.62, RMR: 0.077, Mean communality: 0.281, Variance explained: 0.363
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 2 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53839.06, BIC: 53991.78, RMR: 0.034, Mean communality: 0.317, Variance explained: 0.410
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 3 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53635.21, BIC: 53829.05, RMR: 0.014, Mean communality: 0.326, Variance explained: 0.422
# Factor correlation matrix (Oblimin with Kaiser normalization):
#           Factor 1  Factor 2  Factor 3
# Factor 1     1.000    -0.443    -0.640
# Factor 2    -0.443     1.000     0.534
# Factor 3    -0.640     0.534     1.000
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 4 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53607.50, BIC: 53836.59, RMR: 0.007, Mean communality: 0.341, Variance explained: 0.441
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 5 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53604.63, BIC: 53863.09, RMR: 0.002, Mean communality: 0.336, Variance explained: 0.435
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 6 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53611.18, BIC: 53893.13, RMR: 0.001, Mean communality: 0.306, Variance explained: 0.396
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 7 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53616.72, BIC: 53916.30, RMR: 0.001, Mean communality: 0.298, Variance explained: 0.386
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 8 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 53620.66, BIC: 53931.98, RMR: 0.000, Mean communality: 0.297, Variance explained: 0.384
#
# === Pooled Exp1+Exp2+Exp3 - Interaction block | 9 factor(s) ===
# Rows used: 2628
# Variables tested: 9
# Metrics -> AIC: 54321.05, BIC: 54638.24, RMR: 0.060, Mean communality: 0.263, Variance explained: 0.341
#
# Interaction question factor-loading table (3-factor only, pooled data)
# <style type="text/css">
# #T_cecb8_row3_col2, #T_cecb8_row4_col2, #T_cecb8_row5_col1, #T_cecb8_row6_col1, #T_cecb8_row7_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_cecb8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Experiment</th>
#       <th id="T_cecb8_level0_col0" class="col_heading level0 col0" colspan="3">Pooled Exp1+Exp2+Exp3</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Factor Model</th>
#       <th id="T_cecb8_level1_col0" class="col_heading level1 col0" colspan="3">3-factor</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >Factor</th>
#       <th id="T_cecb8_level2_col0" class="col_heading level2 col0" >factor1</th>
#       <th id="T_cecb8_level2_col1" class="col_heading level2 col1" >factor2</th>
#       <th id="T_cecb8_level2_col2" class="col_heading level2 col2" >factor3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cecb8_level0_row0" class="row_heading level0 row0" >I was in control of my navigation through this interface.</th>
#       <td id="T_cecb8_row0_col0" class="data row0 col0" >-0.799</td>
#       <td id="T_cecb8_row0_col1" class="data row0 col1" >0.042</td>
#       <td id="T_cecb8_row0_col2" class="data row0 col2" >-0.051</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row1" class="row_heading level0 row1" >I had control over the content I wanted to inspect.</th>
#       <td id="T_cecb8_row1_col0" class="data row1 col0" >-0.702</td>
#       <td id="T_cecb8_row1_col1" class="data row1 col1" >-0.131</td>
#       <td id="T_cecb8_row1_col2" class="data row1 col2" >0.288</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row2" class="row_heading level0 row2" >I was in control of the pace of my visit to this interface.</th>
#       <td id="T_cecb8_row2_col0" class="data row2 col0" >-0.555</td>
#       <td id="T_cecb8_row2_col1" class="data row2 col1" >0.070</td>
#       <td id="T_cecb8_row2_col2" class="data row2 col2" >-0.023</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row3" class="row_heading level0 row3" >The interface supported the way I wanted to explore the visualization.</th>
#       <td id="T_cecb8_row3_col0" class="data row3 col0" >-0.127</td>
#       <td id="T_cecb8_row3_col1" class="data row3 col1" >-0.056</td>
#       <td id="T_cecb8_row3_col2" class="data row3 col2" >0.648</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row4" class="row_heading level0 row4" >The interface responded quickly and efficiently to what I wanted to inspect.</th>
#       <td id="T_cecb8_row4_col0" class="data row4 col0" >0.029</td>
#       <td id="T_cecb8_row4_col1" class="data row4 col1" >0.142</td>
#       <td id="T_cecb8_row4_col2" class="data row4 col2" >0.560</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row5" class="row_heading level0 row5" >The interface supported communication with other users who shared my interests.</th>
#       <td id="T_cecb8_row5_col0" class="data row5 col0" >-0.015</td>
#       <td id="T_cecb8_row5_col1" class="data row5 col1" >0.304</td>
#       <td id="T_cecb8_row5_col2" class="data row5 col2" >0.016</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row6" class="row_heading level0 row6" >Interacting with the interface felt like a personal conversation.</th>
#       <td id="T_cecb8_row6_col0" class="data row6 col0" >-0.029</td>
#       <td id="T_cecb8_row6_col1" class="data row6 col1" >0.483</td>
#       <td id="T_cecb8_row6_col2" class="data row6 col2" >-0.044</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row7" class="row_heading level0 row7" >I felt that I could interact meaningfully with the interface.</th>
#       <td id="T_cecb8_row7_col0" class="data row7 col0" >0.008</td>
#       <td id="T_cecb8_row7_col1" class="data row7 col1" >0.396</td>
#       <td id="T_cecb8_row7_col2" class="data row7 col2" >0.125</td>
#     </tr>
#     <tr>
#       <th id="T_cecb8_level0_row8" class="row_heading level0 row8" >The interface felt sensitive to my actions.</th>
#       <td id="T_cecb8_row8_col0" class="data row8 col0" >-0.077</td>
#       <td id="T_cecb8_row8_col1" class="data row8 col1" >0.191</td>
#       <td id="T_cecb8_row8_col2" class="data row8 col2" >0.272</td>
#     </tr>
#   </tbody>
# </table>
# Trust factor-model metrics table (AIC, BIC, root mean residual, mean communality, variance explained)
# <style type="text/css">
# #T_f3493_row1_col1, #T_f3493_row2_col0, #T_f3493_row2_col2, #T_f3493_row2_col3, #T_f3493_row2_col4 {
#   font-weight: bold;
# }
# </style>
# <table id="T_f3493">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Experiment</th>
#       <th id="T_f3493_level0_col0" class="col_heading level0 col0" colspan="5">Experiment 1</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_f3493_level1_col0" class="col_heading level1 col0" >AIC</th>
#       <th id="T_f3493_level1_col1" class="col_heading level1 col1" >BIC</th>
#       <th id="T_f3493_level1_col2" class="col_heading level1 col2" >Root Mean Residual</th>
#       <th id="T_f3493_level1_col3" class="col_heading level1 col3" >Mean Communality</th>
#       <th id="T_f3493_level1_col4" class="col_heading level1 col4" >Variance Explained</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Factor Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3493_level0_row0" class="row_heading level0 row0" >1-factor</th>
#       <td id="T_f3493_row0_col0" class="data row0 col0" >26198.48</td>
#       <td id="T_f3493_row0_col1" class="data row0 col1" >26245.47</td>
#       <td id="T_f3493_row0_col2" class="data row0 col2" >0.093</td>
#       <td id="T_f3493_row0_col3" class="data row0 col3" >0.496</td>
#       <td id="T_f3493_row0_col4" class="data row0 col4" >50.79%</td>
#     </tr>
#     <tr>
#       <th id="T_f3493_level0_row1" class="row_heading level0 row1" >2-factor</th>
#       <td id="T_f3493_row1_col0" class="data row1 col0" >25825.80</td>
#       <td id="T_f3493_row1_col1" class="data row1 col1" >25890.41</td>
#       <td id="T_f3493_row1_col2" class="data row1 col2" >0.008</td>
#       <td id="T_f3493_row1_col3" class="data row1 col3" >0.600</td>
#       <td id="T_f3493_row1_col4" class="data row1 col4" >61.47%</td>
#     </tr>
#     <tr>
#       <th id="T_f3493_level0_row2" class="row_heading level0 row2" >3-factor</th>
#       <td id="T_f3493_row2_col0" class="data row2 col0" >25823.85</td>
#       <td id="T_f3493_row2_col1" class="data row2 col1" >25900.21</td>
#       <td id="T_f3493_row2_col2" class="data row2 col2" >0.000</td>
#       <td id="T_f3493_row2_col3" class="data row2 col3" >0.610</td>
#       <td id="T_f3493_row2_col4" class="data row2 col4" >62.50%</td>
#     </tr>
#     <tr>
#       <th id="T_f3493_level0_row3" class="row_heading level0 row3" >4-factor</th>
#       <td id="T_f3493_row3_col0" class="data row3 col0" >26364.58</td>
#       <td id="T_f3493_row3_col1" class="data row3 col1" >26446.82</td>
#       <td id="T_f3493_row3_col2" class="data row3 col2" >0.111</td>
#       <td id="T_f3493_row3_col3" class="data row3 col3" >0.484</td>
#       <td id="T_f3493_row3_col4" class="data row3 col4" >49.65%</td>
#     </tr>
#   </tbody>
# </table>
# Interaction experience factor-model metrics table (AIC, BIC, root mean residual, mean communality, variance explained)
# <style type="text/css">
# #T_14c6c_row2_col1, #T_14c6c_row3_col3, #T_14c6c_row3_col4, #T_14c6c_row4_col0, #T_14c6c_row7_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_14c6c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Experiment</th>
#       <th id="T_14c6c_level0_col0" class="col_heading level0 col0" colspan="5">Experiment 1</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Metric</th>
#       <th id="T_14c6c_level1_col0" class="col_heading level1 col0" >AIC</th>
#       <th id="T_14c6c_level1_col1" class="col_heading level1 col1" >BIC</th>
#       <th id="T_14c6c_level1_col2" class="col_heading level1 col2" >Root Mean Residual</th>
#       <th id="T_14c6c_level1_col3" class="col_heading level1 col3" >Mean Communality</th>
#       <th id="T_14c6c_level1_col4" class="col_heading level1 col4" >Variance Explained</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Factor Model</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14c6c_level0_row0" class="row_heading level0 row0" >1-factor</th>
#       <td id="T_14c6c_row0_col0" class="data row0 col0" >54513.89</td>
#       <td id="T_14c6c_row0_col1" class="data row0 col1" >54619.62</td>
#       <td id="T_14c6c_row0_col2" class="data row0 col2" >0.077</td>
#       <td id="T_14c6c_row0_col3" class="data row0 col3" >0.281</td>
#       <td id="T_14c6c_row0_col4" class="data row0 col4" >36.30%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row1" class="row_heading level0 row1" >2-factor</th>
#       <td id="T_14c6c_row1_col0" class="data row1 col0" >53839.06</td>
#       <td id="T_14c6c_row1_col1" class="data row1 col1" >53991.78</td>
#       <td id="T_14c6c_row1_col2" class="data row1 col2" >0.034</td>
#       <td id="T_14c6c_row1_col3" class="data row1 col3" >0.317</td>
#       <td id="T_14c6c_row1_col4" class="data row1 col4" >40.99%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row2" class="row_heading level0 row2" >3-factor</th>
#       <td id="T_14c6c_row2_col0" class="data row2 col0" >53635.21</td>
#       <td id="T_14c6c_row2_col1" class="data row2 col1" >53829.05</td>
#       <td id="T_14c6c_row2_col2" class="data row2 col2" >0.014</td>
#       <td id="T_14c6c_row2_col3" class="data row2 col3" >0.326</td>
#       <td id="T_14c6c_row2_col4" class="data row2 col4" >42.22%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row3" class="row_heading level0 row3" >4-factor</th>
#       <td id="T_14c6c_row3_col0" class="data row3 col0" >53607.50</td>
#       <td id="T_14c6c_row3_col1" class="data row3 col1" >53836.59</td>
#       <td id="T_14c6c_row3_col2" class="data row3 col2" >0.007</td>
#       <td id="T_14c6c_row3_col3" class="data row3 col3" >0.341</td>
#       <td id="T_14c6c_row3_col4" class="data row3 col4" >44.10%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row4" class="row_heading level0 row4" >5-factor</th>
#       <td id="T_14c6c_row4_col0" class="data row4 col0" >53604.63</td>
#       <td id="T_14c6c_row4_col1" class="data row4 col1" >53863.09</td>
#       <td id="T_14c6c_row4_col2" class="data row4 col2" >0.002</td>
#       <td id="T_14c6c_row4_col3" class="data row4 col3" >0.336</td>
#       <td id="T_14c6c_row4_col4" class="data row4 col4" >43.50%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row5" class="row_heading level0 row5" >6-factor</th>
#       <td id="T_14c6c_row5_col0" class="data row5 col0" >53611.18</td>
#       <td id="T_14c6c_row5_col1" class="data row5 col1" >53893.13</td>
#       <td id="T_14c6c_row5_col2" class="data row5 col2" >0.001</td>
#       <td id="T_14c6c_row5_col3" class="data row5 col3" >0.306</td>
#       <td id="T_14c6c_row5_col4" class="data row5 col4" >39.59%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row6" class="row_heading level0 row6" >7-factor</th>
#       <td id="T_14c6c_row6_col0" class="data row6 col0" >53616.72</td>
#       <td id="T_14c6c_row6_col1" class="data row6 col1" >53916.30</td>
#       <td id="T_14c6c_row6_col2" class="data row6 col2" >0.001</td>
#       <td id="T_14c6c_row6_col3" class="data row6 col3" >0.298</td>
#       <td id="T_14c6c_row6_col4" class="data row6 col4" >38.59%</td>
#     </tr>
#     <tr>
#       <th id="T_14c6c_level0_row7" class="row_heading level0 row7" >8-factor</th>
#       <td id="T_14c6c_row7_col0" class="data row7 col0" >53620.66</td>
#       <td id="T_14c6c_row7_col1" class="data row7 col1" >53931.98</td>
#       <td id="T_14c6c_row7_col2" class="data row7 col2" >0.000</td>
#       <td id="T_14c6c_row7_col3" class="data row7 col3" >0.297</td>
#       <td id="T_14c6c_row7_col4" class="data row7 col4" >38.45%</td>
#     </tr>
#   </tbody>
# </table>
# Interaction metric trend figure (BIC) written to: /Users/songwen/Documents/Code Lab/Interact4Trust/analysis_outputs/pooled/interaction-factor-bic.png
# Interaction metric trend figure (Normalized BIC) written to: /Users/songwen/Documents/Code Lab/Interact4Trust/analysis_outputs/pooled/interaction-factor-bic-normalized.png
# Interaction metric trend figure (Root Mean Residual) written to: /Users/songwen/Documents/Code Lab/Interact4Trust/analysis_outputs/pooled/interaction-factor-rmr.png
# Interaction metrics LaTeX table written to: /Users/songwen/Documents/Code Lab/Interact4Trust/interaction-factor-metrics-pooled.tex
# LaTeX table written to: /Users/songwen/Documents/Code Lab/Interact4Trust/factor-pooled.tex
